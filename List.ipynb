# %%
class Node:
  def __init__ (self, init_data):
    self.data = init_data
    self.next = None
  def get_data(self):
    return self.data
  def get_next(self):
    return self.next
  def set_data (self, new_data):
    self.data = new_data
  def set_next(self, new_next):
    self.next = new_next

temp = Node (93)
temp.get_data()

b = Node (6)
a = Node (9)
a.set_next (b)
c = Node (4)
b.set_next (c)

print(a.get_next().get_data())
print(b.get_next().get_data())
print(a.get_data())
# Out:
# 6
# 4
# 9

# %%
class Node:
    def __init__(self, init_data):
        self.data = init_data
        self.next = None

    def get_data(self):
        return self.data

    def get_next(self):
        return self.next

    def set_data(self, new_data):
        self.data = new_data

    def set_next(self, new_next):
        self.next = new_next

class UnorderedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        return self.head == None

    def add(self, item):
        temp = Node(item)
        temp.set_next(self.head)
        self.head = temp

    def size(self):
        current = self.head
        count = 0
        while current != None:
            count = count + 1
            current = current.get_next()
        return count

    def search(self, item):
        current = self.head
        found = False
        while current != None and not found:
            if current.get_data() == item:
                found = True
            else:
                current = current.get_next()
        return found

    def remove(self, item):
        current = self.head
        previous = None
        found = False
        while not found:
            if current.get_data() == item:
                found = True
            else:
                previous = current
                current = current.get_next()

        if previous == None:
            self.head = current.get_next()
        else:
            previous.set_next(current.get_next())


mylist = UnorderedList()

mylist.add(74)
mylist.add(17)
mylist.add(33)
mylist.add(92)
mylist.add(54)
print("Apakah 33 ada dalam list?", mylist.search(33))
print("Apakah 29 ada dalam list?", mylist.search(29))
print("Ukuran list:", mylist.size())
mylist.remove(17)
mylist.remove(92)
print("Apakah 92 masih ada dalam list setelah dihapus?", mylist.search(92))
# Out:
# Apakah 33 ada dalam list? True
# Apakah 29 ada dalam list? False
# Ukuran list: 5
# Apakah 92 masih ada dalam list setelah dihapus? False

# %%
class Node:
  def __init__ (self, init_data):
    self.data = init_data
    self.next = None
  def get_data(self):
    return self.data
  def get_next(self):
    return self.next
  def set_data (self, new_data):
    self.data = new_data
  def set_next(self, new_next):
    self.next = new_next

temp = Node (93)
temp.get_data()

b = Node (7)
a = Node (9)
a.set_next (b)
c = Node (1)
print(a.get_next().get_data())
d = Node (2)
b.set_next (d)
d.set_next (c)
c.set_data (12)

print(a.get_next().get_data())
print(b.get_next().get_data())
print(c.get_data())
# Out:
# 7
# 7
# 2
# 12

# %%
class Node:
    def __init__(self, init_data):
        self.data = init_data
        self.next = None

    def get_data(self):
        return self.data

    def get_next(self):
        return self.next

    def set_data(self, new_data):
        self.data = new_data

    def set_next(self, new_next):
        self.next = new_next

class UnorderedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        return self.head == None

    def add(self, item):
        temp = Node(item)
        temp.set_next(self.head)
        self.head = temp

    def size(self):
        current = self.head
        count = 0
        while current != None:
            count = count + 1
            current = current.get_next()
        return count

    def search(self, item):
        current = self.head
        found = False
        while current != None and not found:
            if current.get_data() == item:
                found = True
            else:
                current = current.get_next()
        return found

    def remove(self, item):
        current = self.head
        previous = None
        found = False
        while not found:
            if current.get_data() == item:
                found = True
            else:
                previous = current
                current = current.get_next()

        if previous == None:
            self.head = current.get_next()
        else:
            previous.set_next(current.get_next())


mylist = UnorderedList()

mylist.add(42)
mylist.add(74)
mylist.add(17)
mylist.add(33)
mylist.add(92)
mylist.add(54)
print (mylist.search(33))
print(mylist.size())
mylist.remove(17)
mylist.remove(74)
print(mylist.search(74))
# Out:
# True
# 6
# False

# %%
def print_chain(n):
  while not n == None:
    print(n.get_data(), end = " ")
    n = n.get_next()

 n1 = Node('Teknik')
 n2 = Node(2020)
 n3 = Node('ITTP')
 n4 = Node('Biomedis')
 n2.set_next(n1)
 n4.set_next(n3)
 n3.set_next(n2)
 n1.set_next(None)
 print_chain(n3)
 print()
# Out:
#   File "<tokenize>", line 6
#     n1 = Node('Teknik')
#     ^
# IndentationError: unindent does not match any outer indentation level
