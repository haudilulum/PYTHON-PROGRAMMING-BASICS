# %%
#Bubble_Sort
def bubble_sort(a_list):
  for pass_num in range(len(a_list) - 1, 0, -1):
    for i in range(pass_num):
      if a_list[i] > a_list[i + 1]:
        a_list[i], a_list[i + 1] = a_list[i + 1], a_list[i]
  return a_list

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('Sebelum diurutkan: ', contoh_list)
sorted_list = bubble_sort(contoh_list)
print('Setelah diurutkan: ', sorted_list)
# Out:
# Sebelum diurutkan:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Setelah diurutkan:  [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
#Selection_Sort
def selection_sort(a_list):
    for fill_slot in range(len(a_list) - 1, 0, -1):
        pos_of_max = 0
        for location in range(1, fill_slot + 1):
          if a_list[location] > a_list[pos_of_max]:
              pos_of_max = location

        temp = a_list[fill_slot]
        a_list[fill_slot] = a_list[pos_of_max]
        a_list[pos_of_max] = temp
    return a_list

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('sebelum diurutkan: ', contoh_list)
sorted_list = selection_sort(contoh_list)
print('setelah diurutkan: ',sorted_list)
# Out:
# sebelum diurutkan:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# setelah diurutkan:  [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
#Insertion_Sort
def insertion_sort(a_list):
    for index in range(1, len(a_list)):
        current_value = a_list[index]
        position = index
        while position > 0 and a_list[position - 1] > current_value:
          a_list[position] = a_list[position - 1]
          position = position - 1
        a_list[position] = current_value
    return a_list

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('sebelum diurutkan: ', contoh_list)
sorted_list = insertion_sort(contoh_list)
print('sebelum diurutkan: ',sorted_list)
# Out:
# sebelum diurutkan:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# sebelum diurutkan:  [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
#Shell_Sort
def shell_sort(a_list):
    sublist_count = len(a_list) // 3
    while sublist_count > 0:
      for start_position in range(sublist_count):
          gap_insertion_sort(a_list, start_position, sublist_count)
      print('setelah kenaikan', sublist_count, 'list menjadi', a_list)
      sublist_count = sublist_count // 3
    return a_list

def gap_insertion_sort(a_list, start, gap):
    for i in range(start + gap, len(a_list), gap):
      current_value = a_list[i]
      position = i
      while position >= gap and a_list[position - gap] > current_value:
          a_list[position] = a_list[position - gap]
          position = position - gap
          a_list[position] = current_value

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('sebelum diurutkan: ', contoh_list)
sorted_list = shell_sort(contoh_list)
print('setelah diurutkan: ',sorted_list)
# Out:
# sebelum diurutkan:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# setelah kenaikan 3 list menjadi [17, 26, 20, 44, 55, 31, 54, 77, 93]
# setelah kenaikan 1 list menjadi [17, 20, 26, 31, 44, 54, 55, 77, 93]
# setelah diurutkan:  [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
#Merge_Sort
def merge_sort(a_list):
    print("Memecah", a_list)
    if len(a_list) > 1:
        mid = len(a_list) // 2
        left_half = a_list[:mid]
        right_half = a_list[mid:]
        merge_sort(left_half)
        merge_sort(right_half)
        i = 0
        j = 0
        k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                a_list[k] = left_half[i]
                i += 1
            else:
                a_list[k] = right_half[j]
                j += 1
            k += 1
        while i < len(left_half):
            a_list[k] = left_half[i]
            i += 1
            k += 1
        while j < len(right_half):
            a_list[k] = right_half[j]
            j += 1
            k += 1
    print("Menggabungkan", a_list)
    return a_list

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('Sebelum diurutkan:', contoh_list)
sorted_list = merge_sort(contoh_list)
print('Setelah diurutkan:',sorted_list)
# Out:
# Sebelum diurutkan: [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Memecah [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Memecah [54, 26, 93, 17]
# Memecah [54, 26]
# Memecah [54]
# Menggabungkan [54]
# Memecah [26]
# Menggabungkan [26]
# Menggabungkan [26, 54]
# Memecah [93, 17]
# Memecah [93]
# Menggabungkan [93]
# Memecah [17]
# Menggabungkan [17]
# Menggabungkan [17, 93]
# Menggabungkan [17, 26, 54, 93]
# Memecah [77, 31, 44, 55, 20]
# Memecah [77, 31]
# Memecah [77]
# Menggabungkan [77]
# Memecah [31]
# Menggabungkan [31]
# Menggabungkan [31, 77]
# Memecah [44, 55, 20]
# Memecah [44]
# Menggabungkan [44]
# Memecah [55, 20]
# Memecah [55]
# Menggabungkan [55]
# Memecah [20]
# Menggabungkan [20]
# Menggabungkan [20, 55]
# Menggabungkan [20, 44, 55]
# Menggabungkan [20, 31, 44, 55, 77]
# Menggabungkan [17, 20, 26, 31, 44, 54, 55, 77, 93]
# Setelah diurutkan: [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
#Quick_Sort
def partition(array, start, end):
    pivot = array[start]
    low = start + 1
    high = end
    while True:
        while low <= high and array[high] >= pivot:
            high = high - 1
        while low <= high and array[low] <= pivot:
            low = low + 1
        if low <= high:
            array[low], array[high] = array[high], array[low]
        else:
            break
    array[start], array[high] = array[high], array[start]
    return high

def quick_sort(array, start, end):
    if start >= end:
        return
    p = partition(array, start, end)
    quick_sort(array, start, p - 1)
    quick_sort(array, p + 1, end)

contoh_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
print('Sebelum diurutkan:', contoh_list)
quick_sort(contoh_list, 0, len(contoh_list) - 1)
print('Setelah diurutkan:',contoh_list)
# Out:
# Sebelum diurutkan: [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Setelah diurutkan: [17, 20, 26, 31, 44, 54, 55, 77, 93]
