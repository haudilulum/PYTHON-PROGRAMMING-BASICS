# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
# !cp /content/drive/MyDrive/Colab\ Notebooks/mymodule.py /content

# %%
import mymodule

mymodule.greeting("haudil berhasil mengimpor data")
# Out:
# Hello, haudil berhasil mengimpor data

# %%
import mymodule

a = mymodule.personl["name"]
print(a)
# Out:
# Haudil

# %%
from mymodule import personl

print (personl["age"])
# Out:
# 19

# %%
import mymodule as mx

a = mx.personl ["country"]
print(a)
# Out:
# Indonesia
